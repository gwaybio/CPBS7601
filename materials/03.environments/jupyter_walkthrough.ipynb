# %% [markdown]
# # Introduction to Jupyter Notebooks
#
# ## What is Jupyter Notebook?
#
# An open-source web application that allows you to create and share documents with live code, equations, visualizations, and  text.
#
# ## Purpose and Benefits
#
# - Facilitates interactive computing and data exploration.
# - Supports multiple programming languages (e.g., Python, R, Julia).
# - Data analysis pipelines for reproducible research.
# - Compile publication quality figures
#
# ## Common workflows
#
# - **Path A** Input data -> wrangle data -> test hypothesis -> output results
# - **Path B** Input data -> wrangle data -> visualize results -> output figure

# %%
# Import the packages you are going to use
# Do this after you introduce your notebook in cell 1 with documentation
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Core Components of Jupyter Notebooks
#
# ### Notebook Interface
#
# - **Code cells**: Where you write and execute code.
# - **Markdown cells**: For adding explanations, text, and formatting.
# - **Output cells**: Where the results of code execution are displayed.
#
# _This is a markdown cell_

# %%
# This is a code cell
print("I am going to output this in an 'output cell'")
# Out:
# I am going to output this in an 'output cell'

# %% [markdown]
# ### Kernel
#
# - The computational engine that executes the code contained in a notebook.
# - Supports multiple languages.
# - You can customize kernels using conda environments.
#
# _lets check out our current kernel_

# %%
# The exclamation mark is a special magic command that accesses the terminal
# from a code cell.
! conda list
# Out:
# # packages in environment at /Users/waygr/miniconda3/envs/cpbs7601:
# #
# # Name                    Version                   Build  Channel
# _r-mutex                  1.0.1               anacondar_1    conda-forge
# aiohttp                   3.9.5           py311h05b510d_0    conda-forge
# aiosignal                 1.3.1              pyhd8ed1ab_0    conda-forge
# ansicolors                1.1.8              pyhd8ed1ab_0    conda-forge
# anyio                     4.6.2.post1        pyhd8ed1ab_0    conda-forge
# appnope                   0.1.4              pyhd8ed1ab_0    conda-forge
# argon2-cffi               23.1.0             pyhd8ed1ab_0    conda-forge
# argon2-cffi-bindings      21.2.0          py311h460d6c5_5    conda-forge
# arrow                     1.3.0              pyhd8ed1ab_0    conda-forge
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# async-lru                 2.0.4              pyhd8ed1ab_0    conda-forge
# attrs                     24.2.0             pyh71513ae_0    conda-forge
# babel                     2.16.0             pyhd8ed1ab_0    conda-forge
# backports.zoneinfo        0.2.1           py311h267d04e_9    conda-forge
# beautifulsoup4            4.12.3             pyha770c72_0    conda-forge
# bleach                    6.2.0              pyhd8ed1ab_0    conda-forge
# brotli                    1.1.0                hd74edd7_2    conda-forge
# brotli-bin                1.1.0                hd74edd7_2    conda-forge
# brotli-python             1.1.0           py311h3f08180_2    conda-forge
# bwidget                   1.9.14               hce30654_1    conda-forge
# bzip2                     1.0.8                h99b78c6_7    conda-forge
# c-ares                    1.34.3               h5505292_1    conda-forge
# ca-certificates           2025.10.5            hbd8a1cb_0    conda-forge
# cached-property           1.5.2                hd8ed1ab_1    conda-forge
# cached_property           1.5.2              pyha770c72_1    conda-forge
# cairo                     1.18.4               h6a3b0d2_0    conda-forge
# cctools_osx-arm64         1010.6               h3f5b1a0_2    conda-forge
# certifi                   2025.10.5          pyhd8ed1ab_0    conda-forge
# cffi                      1.17.1          py311h3a79f62_0    conda-forge
# cfgv                      3.4.0                    pypi_0    pypi
# charset-normalizer        3.4.0              pyhd8ed1ab_0    conda-forge
# clang                     19.1.4          default_h1ffe849_0    conda-forge
# clang-19                  19.1.4          default_hf90f093_0    conda-forge
# clang_impl_osx-arm64      19.1.4              ha37d527_23    conda-forge
# clang_osx-arm64           19.1.4              h07b0088_23    conda-forge
# clangxx                   19.1.4          default_h1ffe849_0    conda-forge
# clangxx_impl_osx-arm64    19.1.4              h7361f83_23    conda-forge
# clangxx_osx-arm64         19.1.4              h07b0088_23    conda-forge
# click                     8.1.7           unix_pyh707e725_0    conda-forge
# colorama                  0.4.6              pyhd8ed1ab_0    conda-forge
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# compiler-rt               19.1.4               hd2aecb6_0    conda-forge
# compiler-rt_osx-arm64     19.1.4               h3e8b5a0_0    conda-forge
# contourpy                 1.3.1           py311h210dab8_0    conda-forge
# curl                      8.14.1               h73640d1_0    conda-forge
# cycler                    0.12.1             pyhd8ed1ab_0    conda-forge
# debugpy                   1.8.9           py311h155a34a_0    conda-forge
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# defusedxml                0.7.1              pyhd8ed1ab_0    conda-forge
# distlib                   0.3.9                    pypi_0    pypi
# entrypoints               0.4                pyhd8ed1ab_0    conda-forge
# exceptiongroup            1.2.2              pyhd8ed1ab_0    conda-forge
# executing                 2.1.0              pyhd8ed1ab_0    conda-forge
# filelock                  3.16.1                   pypi_0    pypi
# font-ttf-dejavu-sans-mono 2.37                 hab24e00_0    conda-forge
# font-ttf-inconsolata      3.000                h77eed37_0    conda-forge
# font-ttf-source-code-pro  2.038                h77eed37_0    conda-forge
# font-ttf-ubuntu           0.83                 h77eed37_3    conda-forge
# fontconfig                2.15.0               h1383a14_1    conda-forge
# fonts-conda-ecosystem     1                             0    conda-forge
# fonts-conda-forge         1                             0    conda-forge
# fonttools                 4.55.0          py311h4921393_0    conda-forge
# fqdn                      1.5.1              pyhd8ed1ab_0    conda-forge
# freetype                  2.13.3               hce30654_1    conda-forge
# fribidi                   1.0.10               h27ca646_0    conda-forge
# frozenlist                1.5.0           py311hae2e1ce_0    conda-forge
# gfortran_impl_osx-arm64   13.2.0               h252ada1_3    conda-forge
# gfortran_osx-arm64        13.2.0               h57527a5_1    conda-forge
# gmp                       6.3.0                h7bae524_2    conda-forge
# graphite2                 1.3.13            hebf3989_1003    conda-forge
# gsl                       2.7                  h6e638da_0    conda-forge
# h11                       0.14.0             pyhd8ed1ab_0    conda-forge
# h2                        4.1.0              pyhd8ed1ab_0    conda-forge
# harfbuzz                  11.3.3               hcb8449c_0    conda-forge
# hpack                     4.0.0              pyh9f0ad1d_0    conda-forge
# httpcore                  1.0.7              pyh29332c3_1    conda-forge
# httpx                     0.27.2             pyhd8ed1ab_0    conda-forge
# hyperframe                6.0.1              pyhd8ed1ab_0    conda-forge
# icu                       75.1                 hfee45f7_0    conda-forge
# identify                  2.6.2                    pypi_0    pypi
# idna                      3.10               pyhd8ed1ab_0    conda-forge
# importlib-metadata        8.5.0              pyha770c72_0    conda-forge
# importlib_resources       6.4.5              pyhd8ed1ab_0    conda-forge
# ipykernel                 6.30.1             pyh92f572d_0    conda-forge
# ipython                   8.29.0             pyh707e725_0    conda-forge
# ipywidgets                8.1.5              pyhd8ed1ab_0    conda-forge
# isl                       0.26            imath32_h347afa1_101    conda-forge
# isoduration               20.11.0            pyhd8ed1ab_0    conda-forge
# jedi                      0.19.2             pyhff2d567_0    conda-forge
# jinja2                    3.1.4              pyhd8ed1ab_0    conda-forge
# json5                     0.9.28             pyhff2d567_0    conda-forge
# jsonpointer               3.0.0           py311h267d04e_1    conda-forge
# jsonschema                4.23.0             pyhd8ed1ab_0    conda-forge
# jsonschema-specifications 2024.10.1          pyhd8ed1ab_0    conda-forge
# jsonschema-with-format-nongpl 4.23.0               hd8ed1ab_0    conda-forge
# jupyter                   1.0.0             pyhd8ed1ab_10    conda-forge
# jupyter-lsp               2.2.5              pyhd8ed1ab_0    conda-forge
# jupyter_client            8.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_console           6.6.3              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2              pyh31011fe_1    conda-forge
# jupyter_events            0.10.0             pyhd8ed1ab_0    conda-forge
# jupyter_server            2.14.2             pyhd8ed1ab_0    conda-forge
# jupyter_server_terminals  0.5.3              pyhd8ed1ab_0    conda-forge
# jupyterlab                4.2.6              pyhff2d567_0    conda-forge
# jupyterlab_pygments       0.3.0              pyhd8ed1ab_1    conda-forge
# jupyterlab_server         2.27.3             pyhd8ed1ab_0    conda-forge
# jupyterlab_widgets        3.0.13             pyhd8ed1ab_0    conda-forge
# kiwisolver                1.4.7           py311h2c37856_0    conda-forge
# krb5                      1.21.3               h237132a_0    conda-forge
# lcms2                     2.16                 ha0e7c42_0    conda-forge
# ld64_osx-arm64            951.9                hb91ea2e_2    conda-forge
# lerc                      4.0.0                h9a09cb3_0    conda-forge
# libasprintf               0.25.1               h493aca8_0    conda-forge
# libblas                   3.9.0           25_osxarm64_openblas    conda-forge
# libbrotlicommon           1.1.0                hd74edd7_2    conda-forge
# libbrotlidec              1.1.0                hd74edd7_2    conda-forge
# libbrotlienc              1.1.0                hd74edd7_2    conda-forge
# libcblas                  3.9.0           25_osxarm64_openblas    conda-forge
# libclang-cpp19.1          19.1.4          default_hf90f093_0    conda-forge
# libcurl                   8.14.1               h73640d1_0    conda-forge
# libcxx                    19.1.4               ha82da77_0    conda-forge
# libcxx-devel              19.1.4               h6dc3340_0    conda-forge
# libdeflate                1.22                 hd74edd7_0    conda-forge
# libedit                   3.1.20191231         hc8eb9b7_2    conda-forge
# libev                     4.33                 h93a5062_2    conda-forge
# libexpat                  2.7.1                hec049ff_0    conda-forge
# libffi                    3.4.6                h1da3d7d_1    conda-forge
# libfreetype               2.13.3               hce30654_1    conda-forge
# libfreetype6              2.13.3               h1d14073_1    conda-forge
# libgettextpo              0.25.1               h493aca8_0    conda-forge
# libgfortran               5.0.0           14_2_0_h6c33f7e_103    conda-forge
# libgfortran-devel_osx-arm64 13.2.0               h5d7a38c_3    conda-forge
# libgfortran5              14.2.0             h6c33f7e_103    conda-forge
# libgit2                   1.9.1                h41192e5_0    conda-forge
# libglib                   2.84.3               h587fa63_0    conda-forge
# libiconv                  1.18                 h23cfdf5_2    conda-forge
# libintl                   0.25.1               h493aca8_0    conda-forge
# libjpeg-turbo             3.1.0                h5505292_0    conda-forge
# liblapack                 3.9.0           25_osxarm64_openblas    conda-forge
# libllvm19                 19.1.4               hc4b4ae8_0    conda-forge
# liblzma                   5.8.1                h39f12f2_2    conda-forge
# liblzma-devel             5.8.1                h39f12f2_2    conda-forge
# libnghttp2                1.64.0               h6d7220d_0    conda-forge
# libopenblas               0.3.28          openmp_hf332438_1    conda-forge
# libpng                    1.6.50               h280e0eb_1    conda-forge
# libsodium                 1.0.20               h99b78c6_0    conda-forge
# libsqlite                 3.50.4               h4237e3c_0    conda-forge
# libssh2                   1.11.1               h9cc3647_0    conda-forge
# libtiff                   4.7.0                hfce79cd_1    conda-forge
# libuv                     1.49.2               h7ab814d_0    conda-forge
# libwebp-base              1.4.0                h93a5062_0    conda-forge
# libxcb                    1.17.0               hdb1d25a_0    conda-forge
# libxml2                   2.13.5               hbbdcc80_0    conda-forge
# libzlib                   1.3.1                h8359307_2    conda-forge
# llvm-openmp               19.1.4               hdb05f8b_0    conda-forge
# llvm-tools                19.1.4               hd2aecb6_0    conda-forge
# llvm-tools-19             19.1.4               h87a4c7e_0    conda-forge
# make                      4.4.1                hc9fafa5_2    conda-forge
# markupsafe                3.0.2           py311h56c23cb_0    conda-forge
# matplotlib                3.10.6          py311ha1ab1f8_0    conda-forge
# matplotlib-base           3.10.6          py311h66dac5a_0    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# mistune                   3.0.2              pyhd8ed1ab_0    conda-forge
# mizani                    0.9.3              pyhd8ed1ab_0    conda-forge
# mpc                       1.3.1                h8f1351a_1    conda-forge
# mpfr                      4.2.1                hb693164_3    conda-forge
# multidict                 6.1.0           py311h30e7462_1    conda-forge
# munkres                   1.1.4              pyh9f0ad1d_0    conda-forge
# nb_conda_kernels          2.5.1              pyh707e725_2    conda-forge
# nbclient                  0.10.0             pyhd8ed1ab_0    conda-forge
# nbconvert                 7.16.4               hd8ed1ab_1    conda-forge
# nbconvert-core            7.16.4             pyhd8ed1ab_1    conda-forge
# nbconvert-pandoc          7.16.4               hd8ed1ab_1    conda-forge
# nbformat                  5.10.4             pyhd8ed1ab_0    conda-forge
# ncurses                   6.5                  h7bae524_1    conda-forge
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# nodeenv                   1.9.1                    pypi_0    pypi
# notebook                  7.2.2              pyhd8ed1ab_0    conda-forge
# notebook-shim             0.2.4              pyhd8ed1ab_0    conda-forge
# numpy                     1.25.2          py311hb8f3215_0    conda-forge
# openjpeg                  2.5.2                h9f1df11_0    conda-forge
# openssl                   3.5.4                h5503f6c_0    conda-forge
# overrides                 7.7.0              pyhd8ed1ab_0    conda-forge
# packaging                 24.2               pyhff2d567_1    conda-forge
# pandas                    2.0.3           py311h9e438b8_1    conda-forge
# pandoc                    3.5                  hce30654_0    conda-forge
# pandocfilters             1.5.0              pyhd8ed1ab_0    conda-forge
# pango                     1.56.4               h875632e_0    conda-forge
# papermill                 2.6.0              pyhd8ed1ab_2    conda-forge
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# patsy                     1.0.1              pyhff2d567_0    conda-forge
# pcre2                     10.45                ha881caa_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pillow                    11.0.0          py311h3894ae9_0    conda-forge
# pip                       24.3.1             pyh8b19718_0    conda-forge
# pixman                    0.46.4               h81086ad_1    conda-forge
# pkgutil-resolve-name      1.3.10             pyhd8ed1ab_1    conda-forge
# platformdirs              4.3.6              pyhd8ed1ab_0    conda-forge
# plotnine                  0.12.4             pyhd8ed1ab_0    conda-forge
# pre-commit                4.0.1                    pypi_0    pypi
# prometheus_client         0.21.0             pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.48             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.48               hd8ed1ab_0    conda-forge
# propcache                 0.2.0           py311h460d6c5_2    conda-forge
# psutil                    6.1.0           py311hae2e1ce_0    conda-forge
# pthread-stubs             0.4               hd74edd7_1002    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pycparser                 2.22               pyhd8ed1ab_0    conda-forge
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# pyobjc-core               10.3.1          py311h09e6bbd_1    conda-forge
# pyobjc-framework-cocoa    10.3.1          py311h09e6bbd_1    conda-forge
# pyparsing                 3.2.0              pyhd8ed1ab_1    conda-forge
# pysocks                   1.7.1              pyha2e5f31_6    conda-forge
# python                    3.11.13         hc22306f_0_cpython    conda-forge
# python-dateutil           2.9.0.post0        pyhff2d567_0    conda-forge
# python-fastjsonschema     2.20.0             pyhd8ed1ab_0    conda-forge
# python-json-logger        2.0.7              pyhd8ed1ab_0    conda-forge
# python-tzdata             2024.2             pyhd8ed1ab_0    conda-forge
# python_abi                3.11                    5_cp311    conda-forge
# pytz                      2024.2             pyhd8ed1ab_0    conda-forge
# pyyaml                    6.0.2           py311h460d6c5_1    conda-forge
# pyzmq                     26.2.0          py311h730b646_3    conda-forge
# qhull                     2020.2               h420ef59_5    conda-forge
# qtconsole-base            5.6.1              pyha770c72_0    conda-forge
# qtpy                      2.4.2              pyhdecd6ff_0    conda-forge
# r-askpass                 1.2.1             r43h0d9a900_0    conda-forge
# r-assertthat              0.2.1             r43hc72bb7e_5    conda-forge
# r-backports               1.5.0             r43h07cda29_1    conda-forge
# r-base                    4.3.3               h07f0ef5_18    conda-forge
# r-base64enc               0.1_3           r43h07cda29_1007    conda-forge
# r-bit                     4.5.0             r43h0d9a900_0    conda-forge
# r-bit64                   4.5.2             r43h0d9a900_0    conda-forge
# r-blob                    1.2.4             r43hc72bb7e_2    conda-forge
# r-brew                    1.0_10            r43hc72bb7e_1    conda-forge
# r-brio                    1.1.5             r43h07cda29_1    conda-forge
# r-broom                   1.0.7             r43hc72bb7e_0    conda-forge
# r-bslib                   0.8.0             r43hc72bb7e_0    conda-forge
# r-cachem                  1.1.0             r43h07cda29_1    conda-forge
# r-callr                   3.7.6             r43hc72bb7e_1    conda-forge
# r-cellranger              1.1.0           r43hc72bb7e_1007    conda-forge
# r-cli                     3.6.3             r43hd76f289_1    conda-forge
# r-clipr                   0.8.0             r43hc72bb7e_3    conda-forge
# r-colorspace              2.1_1             r43h07cda29_0    conda-forge
# r-commonmark              1.9.2             r43h0d9a900_0    conda-forge
# r-conflicted              1.2.0             r43h785f33e_2    conda-forge
# r-cpp11                   0.5.0             r43hc72bb7e_0    conda-forge
# r-crayon                  1.5.3             r43hc72bb7e_1    conda-forge
# r-credentials             2.0.2             r43hc72bb7e_0    conda-forge
# r-curl                    5.2.1             r43h5c2fa7e_1    conda-forge
# r-data.table              1.15.4            r43hba8deaf_1    conda-forge
# r-dbi                     1.2.3             r43hc72bb7e_1    conda-forge
# r-dbplyr                  2.5.0             r43hc72bb7e_1    conda-forge
# r-desc                    1.4.3             r43hc72bb7e_1    conda-forge
# r-devtools                2.4.5             r43hc72bb7e_3    conda-forge
# r-diffobj                 0.3.5             r43h07cda29_3    conda-forge
# r-digest                  0.6.37            r43hd76f289_0    conda-forge
# r-downlit                 0.4.4             r43hc72bb7e_1    conda-forge
# r-dplyr                   1.1.4             r43hd76f289_1    conda-forge
# r-dtplyr                  1.3.1             r43hc72bb7e_2    conda-forge
# r-ellipsis                0.3.2             r43h07cda29_3    conda-forge
# r-evaluate                1.0.1             r43hc72bb7e_0    conda-forge
# r-fansi                   1.0.6             r43h07cda29_1    conda-forge
# r-farver                  2.1.2             r43hd76f289_1    conda-forge
# r-fastmap                 1.2.0             r43hd76f289_1    conda-forge
# r-fontawesome             0.5.3             r43hc72bb7e_0    conda-forge
# r-forcats                 1.0.0             r43hc72bb7e_2    conda-forge
# r-fs                      1.6.5             r43h799df56_0    conda-forge
# r-gargle                  1.5.2             r43h785f33e_1    conda-forge
# r-generics                0.1.3             r43hc72bb7e_3    conda-forge
# r-gert                    2.1.5             r43hf6f8396_0    conda-forge
# r-ggplot2                 3.5.2             r43hc72bb7e_0    conda-forge
# r-ggrepel                 0.9.6             r43h088c9a0_1    conda-forge
# r-gh                      1.4.1             r43hc72bb7e_1    conda-forge
# r-gitcreds                0.1.2             r43hc72bb7e_3    conda-forge
# r-glue                    1.8.0             r43h0d9a900_0    conda-forge
# r-googledrive             2.1.1             r43hc72bb7e_2    conda-forge
# r-googlesheets4           1.1.1             r43h785f33e_2    conda-forge
# r-gtable                  0.3.6             r43hc72bb7e_0    conda-forge
# r-haven                   2.5.4             r43hd76f289_1    conda-forge
# r-highr                   0.11              r43hc72bb7e_1    conda-forge
# r-hms                     1.1.3             r43hc72bb7e_2    conda-forge
# r-htmltools               0.5.8.1           r43hd76f289_1    conda-forge
# r-htmlwidgets             1.6.4             r43h785f33e_3    conda-forge
# r-httpuv                  1.6.15            r43hd76f289_1    conda-forge
# r-httr                    1.4.7             r43hc72bb7e_1    conda-forge
# r-httr2                   1.0.6             r43hc72bb7e_0    conda-forge
# r-ids                     1.0.1             r43hc72bb7e_4    conda-forge
# r-ini                     0.3.1           r43hc72bb7e_1006    conda-forge
# r-irdisplay               1.1               r43hd8ed1ab_3    conda-forge
# r-irkernel                1.3.2             r43h785f33e_2    conda-forge
# r-isoband                 0.2.7             r43hd76f289_3    conda-forge
# r-jquerylib               0.1.4             r43hc72bb7e_3    conda-forge
# r-jsonlite                1.8.9             r43h0d9a900_0    conda-forge
# r-knitr                   1.49              r43hc72bb7e_0    conda-forge
# r-labeling                0.4.3             r43hc72bb7e_1    conda-forge
# r-later                   1.3.2             r43hd76f289_1    conda-forge
# r-lattice                 0.22_6            r43h07cda29_1    conda-forge
# r-lifecycle               1.0.4             r43hc72bb7e_1    conda-forge
# r-lubridate               1.9.3             r43h07cda29_1    conda-forge
# r-magrittr                2.0.3             r43h07cda29_3    conda-forge
# r-mass                    7.3_60.0.1        r43h07cda29_1    conda-forge
# r-matrix                  1.6_5             r43hded8dfa_1    conda-forge
# r-memoise                 2.0.1             r43hc72bb7e_3    conda-forge
# r-mgcv                    1.9_1             r43h83b88f1_1    conda-forge
# r-mime                    0.12              r43h07cda29_3    conda-forge
# r-miniui                  0.1.1.1         r43hc72bb7e_1005    conda-forge
# r-modelr                  0.1.11            r43hc72bb7e_2    conda-forge
# r-munsell                 0.5.1             r43hc72bb7e_1    conda-forge
# r-nlme                    3.1_165           r43h7807725_1    conda-forge
# r-openssl                 2.2.2             r43h9b7c17a_0    conda-forge
# r-patchwork               1.3.2             r43hc72bb7e_0    conda-forge
# r-pbdzmq                  0.3_13            r43hd430892_0    conda-forge
# r-pillar                  1.9.0             r43hc72bb7e_2    conda-forge
# r-pkgbuild                1.4.5             r43hc72bb7e_0    conda-forge
# r-pkgconfig               2.0.3             r43hc72bb7e_4    conda-forge
# r-pkgdown                 2.1.1             r43hc72bb7e_0    conda-forge
# r-pkgload                 1.4.0             r43hc72bb7e_0    conda-forge
# r-praise                  1.0.0           r43hc72bb7e_1008    conda-forge
# r-prettyunits             1.2.0             r43hc72bb7e_1    conda-forge
# r-processx                3.8.4             r43h07cda29_1    conda-forge
# r-profvis                 0.4.0             r43h0d9a900_0    conda-forge
# r-progress                1.2.3             r43hc72bb7e_1    conda-forge
# r-promises                1.3.0             r43hd76f289_1    conda-forge
# r-ps                      1.8.1             r43h96f7ad7_0    conda-forge
# r-purrr                   1.0.2             r43h07cda29_1    conda-forge
# r-r6                      2.5.1             r43hc72bb7e_3    conda-forge
# r-ragg                    1.3.3             r43h6144d90_0    conda-forge
# r-rappdirs                0.3.3             r43h07cda29_3    conda-forge
# r-rcmdcheck               1.4.0             r43h785f33e_3    conda-forge
# r-rcolorbrewer            1.1_3             r43h785f33e_3    conda-forge
# r-rcpp                    1.0.13_1          r43h31118f2_0    conda-forge
# r-readr                   2.1.5             r43hd76f289_1    conda-forge
# r-readxl                  1.4.3             r43h0ff08aa_1    conda-forge
# r-rematch                 2.0.0             r43hc72bb7e_1    conda-forge
# r-rematch2                2.1.2             r43hc72bb7e_4    conda-forge
# r-remotes                 2.5.0             r43hc72bb7e_1    conda-forge
# r-repr                    1.1.7             r43h785f33e_1    conda-forge
# r-reprex                  2.1.1             r43hc72bb7e_1    conda-forge
# r-rlang                   1.1.4             r43hd76f289_1    conda-forge
# r-rmarkdown               2.29              r43hc72bb7e_0    conda-forge
# r-roxygen2                7.3.3             r43hc1cd577_0    conda-forge
# r-rprojroot               2.0.4             r43hc72bb7e_1    conda-forge
# r-rstudioapi              0.17.1            r43hc72bb7e_0    conda-forge
# r-rversions               2.1.2             r43hc72bb7e_3    conda-forge
# r-rvest                   1.0.4             r43hc72bb7e_1    conda-forge
# r-sass                    0.4.9             r43hd76f289_1    conda-forge
# r-scales                  1.3.0             r43hc72bb7e_1    conda-forge
# r-selectr                 0.4_2             r43hc72bb7e_4    conda-forge
# r-sessioninfo             1.2.2             r43hc72bb7e_3    conda-forge
# r-shiny                   1.9.1             r43h785f33e_0    conda-forge
# r-sourcetools             0.1.7_1           r43hd76f289_2    conda-forge
# r-stringi                 1.8.4             r43h428a9ab_3    conda-forge
# r-stringr                 1.5.1             r43h785f33e_1    conda-forge
# r-sys                     3.4.3             r43h0d9a900_0    conda-forge
# r-systemfonts             1.1.0             r43hb84c41a_1    conda-forge
# r-testthat                3.2.1.1           r43hd76f289_1    conda-forge
# r-textshaping             1.0.1             r43h0784d17_0    conda-forge
# r-tibble                  3.2.1             r43h07cda29_3    conda-forge
# r-tidyr                   1.3.1             r43hd76f289_1    conda-forge
# r-tidyselect              1.2.1             r43hc72bb7e_1    conda-forge
# r-tidyverse               2.0.0             r43h785f33e_2    conda-forge
# r-timechange              0.3.0             r43hd76f289_1    conda-forge
# r-tinytex                 0.54              r43hc72bb7e_0    conda-forge
# r-tzdb                    0.4.0             r43hd76f289_2    conda-forge
# r-urlchecker              1.0.1             r43hc72bb7e_3    conda-forge
# r-usethis                 3.2.1             r43hc72bb7e_0    conda-forge
# r-utf8                    1.2.4             r43h07cda29_1    conda-forge
# r-uuid                    1.2_1             r43h07cda29_0    conda-forge
# r-vctrs                   0.6.5             r43hd76f289_1    conda-forge
# r-viridislite             0.4.2             r43hc72bb7e_2    conda-forge
# r-vroom                   1.6.5             r43hd76f289_1    conda-forge
# r-waldo                   0.6.1             r43hc72bb7e_0    conda-forge
# r-whisker                 0.4.1             r43hc72bb7e_2    conda-forge
# r-withr                   3.0.2             r43hc72bb7e_0    conda-forge
# r-xfun                    0.48              r43hdd833ad_0    conda-forge
# r-xml2                    1.3.6             r43hdac5c33_2    conda-forge
# r-xopen                   1.0.1             r43hc72bb7e_1    conda-forge
# r-xtable                  1.8_4             r43hc72bb7e_6    conda-forge
# r-yaml                    2.3.10            r43h07cda29_0    conda-forge
# r-zip                     2.3.1             r43h07cda29_1    conda-forge
# readline                  8.2                  h92ec313_1    conda-forge
# referencing               0.35.1             pyhd8ed1ab_0    conda-forge
# requests                  2.32.3             pyhd8ed1ab_0    conda-forge
# rfc3339-validator         0.1.4              pyhd8ed1ab_0    conda-forge
# rfc3986-validator         0.1.1              pyh9f0ad1d_0    conda-forge
# rpds-py                   0.21.0          py311h3ff9189_0    conda-forge
# ruff                      0.14.0               h492a034_0    conda-forge
# scipy                     1.14.1          py311hf1db568_1    conda-forge
# seaborn                   0.13.2               hd8ed1ab_3    conda-forge
# seaborn-base              0.13.2             pyhd8ed1ab_3    conda-forge
# send2trash                1.8.3              pyh31c8845_0    conda-forge
# setuptools                75.6.0             pyhff2d567_0    conda-forge
# sigtool                   0.1.3                h44b9a77_0    conda-forge
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sniffio                   1.3.1              pyhd8ed1ab_0    conda-forge
# soupsieve                 2.5                pyhd8ed1ab_1    conda-forge
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# statsmodels               0.14.4          py311h0f07fe1_0    conda-forge
# tapi                      1300.6.5             h03f4b80_0    conda-forge
# tenacity                  9.0.0              pyhd8ed1ab_0    conda-forge
# terminado                 0.18.1             pyh31c8845_0    conda-forge
# tinycss2                  1.4.0              pyhd8ed1ab_0    conda-forge
# tk                        8.6.13               h5083fa2_1    conda-forge
# tktable                   2.10                 h1e387b8_6    conda-forge
# tomli                     2.1.0              pyhff2d567_0    conda-forge
# tornado                   6.4.1           py311h460d6c5_1    conda-forge
# tqdm                      4.67.1             pyhd8ed1ab_0    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# types-python-dateutil     2.9.0.20241003     pyhff2d567_0    conda-forge
# typing-extensions         4.12.2               hd8ed1ab_0    conda-forge
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# typing_utils              0.1.0              pyhd8ed1ab_0    conda-forge
# tzdata                    2024b                hc8b5060_0    conda-forge
# unicodedata2              15.1.0          py311hae2e1ce_1    conda-forge
# uri-template              1.3.0              pyhd8ed1ab_0    conda-forge
# urllib3                   2.2.3              pyhd8ed1ab_0    conda-forge
# virtualenv                20.27.1                  pypi_0    pypi
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# webcolors                 24.8.0             pyhd8ed1ab_0    conda-forge
# webencodings              0.5.1              pyhd8ed1ab_2    conda-forge
# websocket-client          1.8.0              pyhd8ed1ab_0    conda-forge
# wheel                     0.45.1             pyhd8ed1ab_0    conda-forge
# widgetsnbextension        4.0.13             pyhd8ed1ab_0    conda-forge
# xorg-libxau               1.0.11               hd74edd7_1    conda-forge
# xorg-libxdmcp             1.1.5                hd74edd7_0    conda-forge
# xz                        5.8.1                h9a6d368_2    conda-forge
# xz-gpl-tools              5.8.1                h9a6d368_2    conda-forge
# xz-tools                  5.8.1                h39f12f2_2    conda-forge
# yaml                      0.2.5                h3422bc3_2    conda-forge
# yarl                      1.18.0          py311h917b07b_0    conda-forge
# zeromq                    4.3.5                hc1bb282_7    conda-forge
# zipp                      3.21.0             pyhd8ed1ab_0    conda-forge
# zlib                      1.3.1                h8359307_2    conda-forge
# zstandard                 0.23.0          py311h3696347_3    conda-forge
# zstd                      1.5.7                h6491c7d_2    conda-forge

# %% [markdown]
# ### Jupyter magic commands
#
# `!` is an example of a jupyter magic command
#
# - `!` grants access to the terminal directly in a code cell
# - line magics
# - cell magics
#
# See for more details https://ipython.readthedocs.io/en/stable/interactive/magics.html

# %%
# Example line magic
# %time

2 + 3
# Out:
# CPU times: user 2 μs, sys: 1 μs, total: 3 μs
# Wall time: 6.91 μs
# 5

# %%
# %%capture captured_content_example
print("This is an example showing jupyter cell magic.")

# %%
captured_content_example()
# Out:
# This is an example showing jupyter cell magic.

# %% [markdown]
# ## Key Features
#
# ### Interactive Data Analysis
#
# - Real-time code execution and immediate feedback.
#
# ### Rich Text Support
#
# - Markdown and LaTeX for annotations and mathematical expressions.
#
# $ x = \frac{-b \pm \sqrt{b^2 - 4ac}}{2a} $
#
# ### Visualization Integration
#
# - Support for libraries like Matplotlib, Seaborn, Plotly for data visualization.
#
# ### Export Options
#
# - Export notebooks to various formats: HTML, PDF, Markdown, etc.

# %% [markdown]
# ## Example usage

# %%
flights = sns.load_dataset("flights")

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   month       144 non-null    category
#  2   passengers  144 non-null    int64
# dtypes: category(1), int64(2)
# memory usage: 2.9 KB

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights.passengers.sum()
# Out:
# 40363

# %%
flights.year.unique()
# Out:
# array([1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959,
#        1960])

# %%
# Pivot the data to create a matrix suitable for a heatmap
flights_pivot = flights.pivot(index="month", columns="year", values="passengers")

# Create a heatmap plot using matplotlib
plt.figure(figsize=(10, 8))
plt.imshow(flights_pivot, cmap="YlGnBu", aspect="auto")

# Add color bar
plt.colorbar(label="Number of Passengers")

# Set the tick labels
plt.xticks(range(len(flights_pivot.columns)), flights_pivot.columns)
plt.yticks(range(len(flights_pivot.index)), flights_pivot.index)

# Add labels and title
plt.title("Number of Airline Passengers per Month (1949-1960)")
plt.xlabel("Year")
plt.ylabel("Month")

# Save the plot as an image file
plt.savefig("flights_heatmap.png", dpi=300, bbox_inches="tight")

# Show the plot
plt.show()

# %% [markdown]
# ## Closing tips
#
# - Always make sure that you `restart and run all` cells after you have made all final changes.
#   - Jupyter notebooks are dynamic and can be run out of order.
#   - If your cells are not sequential, then there is no guarantee of reproducibility.
#   - Variables could have been changed in cells that you no longer can see.
# - When you're adding jupyter notebooks to github, it is also super helpful to add something called an `nbconverted` file.
#   - You can save this in an `nbconverted` folder, and it will enable code reviewers to more easily comment on your code
#   - Apply the command `jupyter nbconvert --to script jupyter_walkthrough.ipynb --output-dir nbconverted`
#   - Run this every single time you make changes to the notebook.
#   - It is helpful because any changes to this file is very hard to see in a pull request review. It makes it quite difficult to understand what has actually changed.
#     - See https://github.com/WayScience/CPBS7601/pull/39 for an example of what I mean!
